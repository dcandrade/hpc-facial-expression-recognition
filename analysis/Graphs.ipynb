# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('../results/output_1000epochs_8093train_2013test___2950098091.txt')
df.set_index('epoch', inplace=True)

# %%
print(len(df))
df.head()
# Out:
# 1001
#        accuracy  precision  recall        f1      cost  time
# epoch
# 1      0.506240   0.506240     1.0  0.672190  0.693147   238
# 2      0.506240   0.506240     1.0  0.672190  0.692274   239
# 3      0.507105   0.506678     1.0  0.672577  0.691792   238
# 4      0.507105   0.506678     1.0  0.672577  0.691475   240
# 5      0.507476   0.506866     1.0  0.672742  0.691225   238

# %%
test = df.loc[-1]
train = df.loc[1:1000]
test
# Out:
# accuracy     0.598112
# precision    0.588770
# recall       0.696289
# f1           0.638031
# cost        -1.000000
# time        -1.000000
# Name: -1, dtype: float64

# %%
plot = train.accuracy.plot()
plot.set_title("Acurácia por Época")
plot.set_xlabel("# Época")
plot.set_ylabel("Acurácia")
# Out:
# Text(0,0.5,'Acurácia')

# %%
prplot = train[['precision', 'recall']].set_index('recall').plot()
prplot.set_title("Curva Precision-Recall")
prplot.set_xlabel("Recall")
prplot.set_ylabel("Precision")
# Out:
# Text(0,0.5,'Precision')

# %%
costplot = train['cost'].plot()
costplot.set_title("Custo por Época de Treinamento")
costplot.set_xlabel("Época")
costplot.set_ylabel("Custo")
# Out:
# Text(0,0.5,'Custo')

# %%
costplot = train['f1'].plot()
costplot.set_title("F1 Score por Época de Treinamento")
costplot.set_xlabel("Época")
costplot.set_ylabel("F1 Score")
# Out:
# Text(0,0.5,'F1 Score')
